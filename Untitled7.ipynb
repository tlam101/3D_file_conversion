# %% [markdown]
# <a href="https://colab.research.google.com/github/tlam101/3D_file_conversion/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/My Drive/hubmap-hacking-the-human-vasculature.zip"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import os, glob

# %%
df = pd.read_csv("wsi_meta.csv")

df.head()
# Out:
#    source_wsi  age sex race  height  weight   bmi
# 0           1   58   F    W   160.0    59.0  23.0
# 1           2   56   F    W   175.2   139.6  45.5
# 2           3   73   F    W   162.3    87.5  33.2
# 3           4   53   M    B   166.0    73.0  26.5

# %%
tile_df = pd.read_csv("tile_meta.csv")

tile_df.head()
# Out:
#              id  source_wsi  dataset      i      j
# 0  0006ff2aa7cd           2        2  16896  16420
# 1  000e79e206b7           6        3  10240  29184
# 2  00168d1b7522           2        2  14848  14884
# 3  00176a88fdb0           7        3  14848  25088
# 4  0033bbc76b6b           1        1  10240  43008

# %%
root = os.getcwd()
print(root)

train_path = root + "/train"
print(train_path)

train_files = os.listdir(train_path)
for i in range(len(train_files)):
  train_files[i] = train_path + "/" + train_files[i]

print(len(train_files))
print(len(train_files[0]))
# Out:
# /content
# /content/train
# 7033
# /content/train/9bf2e8f5b9c0.tif

# %%
from PIL import Image

fig = plt.figure()
for i in range(9):
  img = Image.open(train_files[i])
  plt.subplot(3,3,i+1)
  plt.imshow(img)

plt.show()

# %%
import json

json_data = []
with open('polygons.jsonl', 'r') as f:
    for line in f:
        json_data.append(json.loads(line))

# %%
json_df = pd.DataFrame(json_data) 

json_df.head()
# Out:
#              id                                        annotations
# 0  0006ff2aa7cd  [{'type': 'glomerulus', 'coordinates': [[[167,...
# 1  00168d1b7522  [{'type': 'glomerulus', 'coordinates': [[[511,...
# 2  0033bbc76b6b  [{'type': 'blood_vessel', 'coordinates': [[[16...
# 3  003504460b3a  [{'type': 'blood_vessel', 'coordinates': [[[40...
# 4  004daf1cbe75  [{'type': 'blood_vessel', 'coordinates': [[[14...
